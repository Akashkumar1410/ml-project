# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.1.2; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\HOME\PycharmProjects\internship2\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

file_path1 = 'C:/Users/HOME/PycharmProjects/Internship2/train.csv'
file_path2 = 'C:/Users/HOME/PycharmProjects/Internship2/test.csv'

# Read the CSV file into a pandas DataFrame
df1= pd.read_csv(file_path1)
df2= pd.read_csv(file_path2)
df1.columns[-1]
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_12416\1981313616.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 'Loan_Status'

# %%
df2
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 357  LP002971   Male     Yes         3+  Not Graduate           Yes
# 358  LP002975   Male     Yes          0      Graduate            No
# 359  LP002980   Male      No          0      Graduate            No
# 360  LP002986   Male     Yes          0      Graduate            No
# 361  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0         110             360.0
# ...

# %%
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df1.info()
print("datafrme 2")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
# datafrme 2
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
df1.columns
# print("dataframe 2 columns")
# df2.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df1
df2

# %%
import pandas as pd

def find_null_values(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Find rows with null values and corresponding columns
    null_rows_with_columns = df[df.isnull().any(axis=1)].apply(lambda row: row.index[row.isnull()].tolist(), axis=1)

    # Print the results
    print(f"\nRows with Null Values and Corresponding Columns in {file_path}:")
    print(null_rows_with_columns)

# List of CSV file paths
csv_files = ['C:/Users/HOME/PycharmProjects/Internship2/train_modified.csv', 'C:/Users/HOME/PycharmProjects/Internship2/test_modified.csv']

# Apply the function to each CSV file
for file_path in csv_files:
    find_null_values(file_path)

# %% [markdown]
# ### fill the loam a mount null values with 0

# %%
import pandas as pd

def fill_null_with_mean_and_save(file_path, column_name):
    try:
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Find mean of the specified column
        mean_value = df[column_name].mean()

        # Fill null values in the specified column with the mean
        df[column_name] = df[column_name].fillna(mean_value)

        # Display the DataFrame after filling null values
        print(f"\nDataFrame after filling null values with mean in '{column_name}' column for {file_path}:")
        print(df)

        # Save the modified DataFrame to the original CSV file
        df.to_csv(file_path, index=False)
        print(f"\nModified DataFrame saved to {file_path}")

    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except pd.errors.EmptyDataError:
        print(f"Empty file: {file_path}")
    except pd.errors.ParserError:
        print(f"Error parsing file: {file_path}")
    except Exception as e:
        print(f"An error occurred for file {file_path}: {e}")

# List of CSV file paths and the column to fill with mean
csv_files = ['C:/Users/HOME/PycharmProjects/Internship2/train_modified.csv', 'C:/Users/HOME/PycharmProjects/Internship2/test_modified.csv']
column_to_fill = 'Loan_Amount_Term'  # Replace 'Your_Column_Name' with the actual column name

# Apply the function to each CSV file
for file_path in csv_files:
    fill_null_with_mean_and_save(file_path, column_to_fill)

# %% [markdown]
# ### fill the categorical null data values with most occuroing values

# %%
import pandas as pd

def fill_null_with_mean_and_save(file_path, column_name):
    try:
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Find mean of the specified column
        mean_value = df[column_name].mean()

        # Fill null values in the specified column with the mean
        df[column_name] = df[column_name].fillna(mean_value)

        # Display the DataFrame after filling null values
        print(f"\nDataFrame after filling null values with mean in '{column_name}' column for {file_path}:")
        print(df)

        # Save the modified DataFrame to the original CSV file
        df.to_csv(file_path, index=False)
        print(f"\nModified DataFrame saved to {file_path}")

    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except pd.errors.EmptyDataError:
        print(f"Empty file: {file_path}")
    except pd.errors.ParserError:
        print(f"Error parsing file: {file_path}")
    except Exception as e:
        print(f"An error occurred for file {file_path}: {e}")

# List of CSV file paths and the column to fill with mean
csv_files = ['C:/Users/HOME/PycharmProjects/Internship2/train_modified.csv', 'C:/Users/HOME/PycharmProjects/Internship2/test_modified.csv']
column_to_fill = 'Loan_Amount_Term'  # Replace 'Your_Column_Name' with the actual column name

# Apply the function to each CSV file
for file_path in csv_files:
    fill_null_with_mean_and_save(file_path, column_to_fill)

# %%
df1

# %%
df2

# %% [markdown]
# ### impute the misiing values with most occuring values

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

def impute_most_frequent_and_save(file_path, columns_to_impute):
    try:
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Create a SimpleImputer instance
        imputer = SimpleImputer(strategy='most_frequent')

        # Fit and transform the imputer on the specified columns
        df[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])

        # Display the DataFrame after imputing null values
        print(f"\nDataFrame after imputing null values in {columns_to_impute} columns for {file_path}:")
        print(df)

        # Save the modified DataFrame to the original CSV file
        df.to_csv(file_path, index=False)
        print(f"\nModified DataFrame saved to {file_path}")

    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except pd.errors.EmptyDataError:
        print(f"Empty file: {file_path}")
    except pd.errors.ParserError:
        print(f"Error parsing file: {file_path}")
    except Exception as e:
        print(f"An error occurred for file {file_path}: {e}")

# List of CSV file paths and columns to impute with most frequent values
csv_files = ['C:/Users/HOME/PycharmProjects/Internship2/train_modified.csv', 'C:/Users/HOME/PycharmProjects/Internship2/test_modified.csv']
columns_to_impute = ['Dependents', 'Gender', 'Married', 'Credit_History', 'Self_Employed']  # Replace with actual column names

# Apply the function to each CSV file
for file_path in csv_files:
    impute_most_frequent_and_save(file_path, columns_to_impute)

# %% [markdown]
# ### printing the modified file

# %%
file_path1 = 'C:/Users/HOME/PycharmProjects/Internship2/train_modified.csv'
file_path2 = 'C:/Users/HOME/PycharmProjects/Internship2/test_modified.csv'

# Read the CSV file into a pandas DataFrame
df1= pd.read_csv(file_path1)
df2= pd.read_csv(file_path2)
df1

# %% [markdown]
# ### remove the operators from the columns

# %%
import pandas as pd

def preprocess_data(file_path):
    try:
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Replace non-numeric characters in the 'Dependents' column
        df['Dependents'] = df['Dependents'].replace('[^\d]', '', regex=True)

        # Convert the 'Dependents' column to numeric type
        df['Dependents'] = pd.to_numeric(df['Dependents'], errors='coerce')

        # Remove extra spaces and convert values to lowercase for all columns
        df = df.applymap(lambda x: str(x).strip().lower() if isinstance(x, str) else x)

        # Display the DataFrame after preprocessing
        print(f"\nDataFrame after preprocessing for {file_path}:")
        print(df)

        # Save the preprocessed DataFrame to the original CSV file
        df.to_csv(file_path, index=False)
        print(f"\nPreprocessed DataFrame saved to {file_path}")

    except FileNotFoundError:
        print(f"File not found: {file_path}")
   
# List of CSV file paths
csv_files = ['C:/Users/HOME/PycharmProjects/Internship2/train_modified.csv', 'C:/Users/HOME/PycharmProjects/Internship2/test_modified.csv']

# Apply the function to each CSV file
for file_path in csv_files:
    preprocess_data(file_path)
df

# %%
df1.info()

# %%
file_path1 = 'C:/Users/HOME/PycharmProjects/Internship2/train_modified.csv'
file_path2 = 'C:/Users/HOME/PycharmProjects/Internship2/test_modified.csv'

# Read the CSV file into a pandas DataFrame
df1= pd.read_csv(file_path1)
df2= pd.read_csv(file_path2)



df1

# %%
df2

# %%
import pandas as pd

def change_float_to_int_and_save(file_path, columns_to_convert):
    try:
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Check if specified columns exist in the DataFrame
        invalid_columns = [col for col in columns_to_convert if col not in df.columns]
        if invalid_columns:
            raise ValueError(f"Invalid columns: {invalid_columns}. Check column names and try again.")

        # Change data type from float to int for specified columns
        df[columns_to_convert] = df[columns_to_convert].astype(int, errors='ignore')

        # Display the DataFrame after changing data type
        print(f"\nDataFrame after changing data type to int for {columns_to_convert} columns in {file_path}:")
        print(df)

        # Save the modified DataFrame to the original CSV file
        df.to_csv(file_path, index=False)
        print(f"\nModified DataFrame saved to {file_path}")

    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except pd.errors.EmptyDataError:
        print(f"Empty file: {file_path}")
    except pd.errors.ParserError:
        print(f"Error parsing file: {file_path}")
    except Exception as e:
        print(f"An error occurred for file {file_path}: {e}")

# List of CSV file paths and columns to convert from float to int
csv_files = ['C:/Users/HOME/PycharmProjects/Internship2/train_modified.csv', 'C:/Users/HOME/PycharmProjects/Internship2/test_modified.csv']
columns_to_convert = ['CoapplicantIncome','Loan_Amount_Term','Credit_History','LoanAmount']  # Replace with actual column names

# Apply the function to each CSV file
for file_path in csv_files:
    change_float_to_int_and_save(file_path, columns_to_convert)

# %% [markdown]
# ### fill the dependents values with th sk-learn imputer

# %%
pip install scikit-learn

# %% [markdown]
# ### Lable encoer for train and test data

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load your CSV file into a pandas DataFrame
train_data = pd.read_csv('train_modified.csv')
test_data = pd.read_csv('test_modified.csv')

# Specify the columns you want to encode
columns_to_encode = ['Gender', 'Married','Education','Self_Employed','Property_Area']# Add your column names here

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit and transform the training data
for column in columns_to_encode:
    train_data[column] = label_encoder.fit_transform(train_data[column])
    test_data[column] = label_encoder.transform(test_data[column])


# Save the transformed data into new CSV files
train_data.to_csv('train_encoded.csv', index=False)
test_data.to_csv('transformed_test_data.csv', index=False)



# Transform the test data using the fitted encoder

    

# # Save the transformed data into new CSV files
# train_data.to_csv('transformed_train_data.csv', index=False)
# test_data.to_csv('transformed_test_data.csv', index=False)

# %%
import pandas as pd

# Load your CSV file into a pandas DataFrame
test_data = pd.read_csv('transformed_test_data.csv')
train_data = pd.read_csv('train_encoded.csv')

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             362 non-null    int64
#  1   Married            362 non-null    int64
#  2   Dependents         362 non-null    int64
#  3   Education          362 non-null    int64
#  4   Self_Employed      362 non-null    int64
#  5   ApplicantIncome    362 non-null    int64
#  6   CoapplicantIncome  362 non-null    int64
#  7   LoanAmount         362 non-null    int64
#  8   Loan_Amount_Term   362 non-null    int64
#  9   Credit_History     362 non-null    int64
#  10  Property_Area      362 non-null    int64
# dtypes: int64(11)
# memory usage: 31.2 KB

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    int64
#  7   LoanAmount         614 non-null    int64
#  8   Loan_Amount_Term   614 non-null    int64
#  9   Credit_History     614 non-null    int64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: int64(12)
# memory usage: 57.7 KB

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load your dataset


# Drop a column (replace 'column_to_drop' with the actual column name)
train_data = train_data.drop(columns=['Loan_ID'])

# Label encode a column (replace 'column_to_encode' with the actual column name)
label_encoder = LabelEncoder()
train_data['Loan_Status'] = label_encoder.fit_transform(train_data['Loan_Status'])

# Save the modified DataFrame to a new file (replace 'modified_file.csv' with your desired file name)
train_data.to_csv('train_data.csv', index=False)

# %%
train_data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
# Assuming 'ColumnName' is the column for which you want to count unique values
unique_counts = train_data['Gender'].value_counts()

# Print or display the unique value counts
print(unique_counts)
# Out:
# Gender
# 1    502
# 0    112
# Name: count, dtype: int64

# %%
# Assuming 'ColumnName' is the column for which you want to count unique values
unique_counts = train_data['Dependents'].value_counts()

# Print or display the unique value counts
print(unique_counts)
# Out:
# Dependents
# 0    360
# 1    102
# 2    101
# 3     51
# Name: count, dtype: int64

# %%
# Assuming 'ColumnName' is the column for which you want to count unique values
unique_counts = train_data['Education'].value_counts()

# Print or display the unique value counts
print(unique_counts)

# %%
# Assuming 'ColumnName' is the column for which you want to count unique values
unique_counts = train_data['Self_Employed'].value_counts()

# Print or display the unique value counts
print(unique_counts)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# List of column names to encode
columns_to_encode = ['Loan_Status']  # Add your column names here

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit and transform the training data for each colum
train_data[column] = label_encoder.fit_transform(train_data[column])

# Save the transformed data into a new CSV file
train_data.to_csv("train_encoded.csv", index=False)

# %%
train_data = pd.read_csv('train_encoded.csv')

# %%
train_data

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Load the training data
train_data = pd.read_csv('train_encoded.csv')

# Explore and preprocess the training data
print("Training Data:")
print(train_data.head())

# Identify the features and target variable
X_train = train_data.drop('Loan_Status', axis=1)
y_train = train_data['Loan_Status']

# Convert categorical variables to numerical using one-hot encoding
X_train = pd.get_dummies(X_train)

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Load the testing data
test_data = pd.read_csv('transformed_test_data.csv')

# Explore and preprocess the testing data
print("\nTesting Data:")
print(test_data.head())

# Identify the features in the testing data
X_test = pd.get_dummies(test_data)  # Assuming similar preprocessing as training data

# Create and train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the validation set
y_pred = model.predict(X_val)

# Evaluate the model performance on the validation set
accuracy = accuracy_score(y_val, y_pred)
print(f"Accuracy on the validation set: {accuracy:.2%}")


# Make predictions on the test set
test_predictions = model.predict(X_test)

# Optional: Save the predictions to a CSV file
# predictions_df = pd.DataFrame({'Loan_Status_Prediction': test_predictions})
# predictions_df.to_csv('test_predictions.csv', index=False)
# Out:
# Training Data:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0           1               360               1
# 1               1508         128               360               1
# 2                  0          66               360               1
# 3               2358         120               360               1
# 4                  0         141               360               1
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
predictions_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 predictions_df.head()
#
# NameError: name 'predictions_df' is not defined

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1-score: {f1}')

# Calculate and print confusion matrix
conf_matrix = confusion_matrix(y_val, y_pred)
print('Confusion Matrix:')
print(conf_matrix)

# Additional classification report
print('Classification Report:')
print(classification_report(y_val, y_pred))
# Out:
# Precision: 0.7596153846153846
# Recall: 0.9875
# F1-score: 0.8586956521739131
# Confusion Matrix:
# [[18 25]
#  [ 1 79]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.42      0.58        43
#            1       0.76      0.99      0.86        80
#
#     accuracy                           0.79       123
#    macro avg       0.85      0.70      0.72       123
# weighted avg       0.83      0.79      0.76       123

# %%
import matplotlib.pyplot as plt

# Precision, Recall, and F1-score values
precision = 0.7596153846153846
recall = 0.9875
f1_score = 0.8586956521739131

# Labels for the bars
labels = ['Precision', 'Recall', 'F1-score']

# Values for the bars
values = [precision, recall, f1_score]

# Plotting the bar graph
plt.figure(figsize=(8, 6))
plt.bar(labels, values, color=['blue', 'green', 'orange'])
plt.title('Precision, Recall, and F1-score')
plt.ylim(0, 1)  # Set y-axis limits between 0 and 1 for better visualization
plt.ylabel('Score')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Make predictions on the validation set
y_pred_proba = model.predict_proba(X_val)[:, 1]

# KDE plot for predicted probabilities
plt.figure(figsize=(8, 6))
sns.kdeplot(y_pred_proba, shade=True, color='skyblue')
plt.title('Kernel Density Estimate (KDE) Plot for Predicted Probabilities')
plt.xlabel('Predicted Probability')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_12416\1651665689.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y_pred_proba, shade=True, color='skyblue')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get feature names after one-hot encoding
feature_names = X_train.columns

# Get coefficients from the logistic regression model
coefficients = model.coef_[0]

# Create a DataFrame with feature names and coefficients
coef_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': coefficients})

# Sort the DataFrame by absolute coefficient values for better visualization
coef_df['Abs_Coefficient'] = coef_df['Coefficient'].abs()
coef_df = coef_df.sort_values(by='Abs_Coefficient', ascending=False)

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x='Coefficient', y='Feature', data=coef_df, palette='coolwarm')
plt.title('Logistic Regression Coefficients')
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.show()
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_12416\2259051791.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Coefficient', y='Feature', data=coef_df, palette='coolwarm')

# %% [markdown]
# ### checking the Outliers in the data

# %%
# !pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the training and testing datasets
train_data = pd.read_csv('train_encoded.csv')

# Select numerical columns (you can modify this based on your actual columns)
numerical_cols = train_data.select_dtypes(include=['float64', 'int64']).columns

# Plot box plots for numerical columns in the training data
plt.figure(figsize=(12, 6))
plt.title('Box Plots for Numerical Columns in Training Data')
sns.boxplot(data=train_data[numerical_cols])
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### removing the out;liers and replace with the mean values

# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore

# Load the original training data
file_path = 'modified_dataset.csv'
train_data = pd.read_csv(file_path)

# # Select columns with numerical data (you can modify this based on your actual columns)
numerical_cols = ['ApplicantIncome']

# # Calculate z-scores for each numerical column
# z_scores = np.abs(zscore(train_data[numerical_cols]))

# # Define a threshold for outlier detection (you can adjust this threshold as needed)
# threshold = 3

# # Identify outliers based on the threshold
# outliers = (z_scores > threshold).any(axis=1)

# # Replace outliers with the mean of the respective column
# for col in numerical_cols:
#     train_data.loc[outliers, col] = train_data[col].mean()

# print("Number of outliers replaced:", outliers.sum())
# train_data.to_csv(file_path, index=False)

# Save the modified training data with outliers replaced
# train_data.to_csv('train_no_outliers.csv', index=False)





# Save the modified training data with outliers replaced to the original file
# train_data.to_csv(file_path, index=False)
numerical_cols = train_data.select_dtypes(include=['float64', 'int64']).columns

# Plot box plots for numerical columns in the training data
plt.figure(figsize=(12, 6))
plt.title('Box Plots for Numerical Columns in Training Data')
sns.boxplot(data=train_data[numerical_cols])
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### train the model with no outliers

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Load the training data with replaced outliers
train_data_with_no_outliers = pd.read_csv('modified_dataset.csv')

# Explore and preprocess the training data
print("Training Data:")
print(train_data_with_no_outliers.head())

# Identify the features and target variable
X_train_no_outliers = train_data_with_no_outliers.drop('Loan_Status', axis=1)
y_train_no_outliers = train_data_with_no_outliers['Loan_Status']

# Convert categorical variables to numerical using one-hot encoding
X_train_no_outliers = pd.get_dummies(X_train_no_outliers)

# Split the training data into training and validation sets
X_train_no_outliers, X_val_no_outliers, y_train_no_outliers, y_val_no_outliers = train_test_split(
    X_train_no_outliers, y_train_no_outliers, test_size=0.2, random_state=42
)

# Load the original testing data
original_test_data = pd.read_csv('transformed_test_data.csv')

# Explore and preprocess the testing data
print("\nTesting Data:")
print(original_test_data.head())

# Identify the features in the testing data
X_test_original = pd.get_dummies(original_test_data)  # Assuming similar preprocessing as training data

# Create and train the logistic regression model
model_no_outliers = LogisticRegression()
model_no_outliers.fit(X_train_no_outliers, y_train_no_outliers)

# Make predictions on the validation set
y_pred_no_outliers = model_no_outliers.predict(X_val_no_outliers)

# Evaluate the model performance on the validation set
accuracy_no_outliers = accuracy_score(y_val_no_outliers, y_pred_no_outliers)
print(f"Accuracy on the validation set: {accuracy_no_outliers:.2%}")

# Make predictions on the original test set
test_predictions_original = model_no_outliers.predict(X_test_original)

# Optional: Save the predictions to a CSV file
predictions_df_original = pd.DataFrame({'Loan_Status_Prediction': test_predictions_original})
# predictions_df_original.to_csv('test_predictions_no_outliers.csv', index=False)
# Out:
# Training Data:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0       3764.10965
# 1       1        1           1          0              0       4583.00000
# 2       1        1           0          0              1       3000.00000
# 3       1        1           0          1              0       2583.00000
# 4       1        0           0          0              0       3764.10965
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         1.0             360.0               1
# 1             1508.0       128.0             360.0               1
# 2                0.0        66.0             360.0               1
# 3             2358.0       120.0             360.0               1
# 4                0.0       141.0             360.0               1
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Make predictions on the validation set
y_pred_no_outliers = model_no_outliers.predict(X_val_no_outliers)

precision_no_outliers = precision_score(y_val_no_outliers, y_pred_no_outliers)
recall_no_outliers = recall_score(y_val_no_outliers, y_pred_no_outliers)
f1_no_outliers = f1_score(y_val_no_outliers, y_pred_no_outliers)

print(f'Precision: {precision_no_outliers}')
print(f'Recall: {recall_no_outliers}')
print(f'F1-score: {f1_no_outliers}')

# Calculate and print confusion matrix
conf_matrix_no_outliers = confusion_matrix(y_val_no_outliers, y_pred_no_outliers)
print('Confusion Matrix:')
print(conf_matrix_no_outliers)

# Additional classification report
print('Classification Report:')
print(classification_report(y_val_no_outliers, y_pred_no_outliers))
# Out:
# Precision: 0.7596153846153846
# Recall: 0.9875
# F1-score: 0.8586956521739131
# Confusion Matrix:
# [[18 25]
#  [ 1 79]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.42      0.58        43
#            1       0.76      0.99      0.86        80
#
#     accuracy                           0.79       123
#    macro avg       0.85      0.70      0.72       123
# weighted avg       0.83      0.79      0.76       123

# %% [markdown]
# # Print the report ot train the model on the scaled data with standard scaler

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from joblib import dump, load


# Load the training data with replaced outliers
train_data_with_no_outliers = pd.read_csv('modified_dataset.csv')

# Identify the features and target variable
X_train_no_outliers = train_data_with_no_outliers.drop('Loan_Status', axis=1)
y_train_no_outliers = train_data_with_no_outliers['Loan_Status']

# Convert categorical variables to numerical using one-hot encoding
X_train_no_outliers = pd.get_dummies(X_train_no_outliers)

# Split the training data into training and validation sets
X_train_no_outliers, X_val_no_outliers, y_train_no_outliers, y_val_no_outliers = train_test_split(
    X_train_no_outliers, y_train_no_outliers, test_size=0.2, random_state=42
)

# Apply StandardScaler to the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_no_outliers)
X_val_scaled = scaler.transform(X_val_no_outliers)

# Load the original testing data
original_test_data = pd.read_csv('transformed_test_data.csv')

# Identify the features in the testing data
X_test_original = pd.get_dummies(original_test_data)  # Assuming similar preprocessing as training data

# Apply StandardScaler to the testing features
X_test_scaled = scaler.transform(X_test_original)

# Create and train the logistic regression model
model_no_outliers_scaled = LogisticRegression()
model_no_outliers_scaled.fit(X_train_scaled, y_train_no_outliers)

# Make predictions on the validation set
y_pred_no_outliers_scaled = model_no_outliers_scaled.predict(X_val_scaled)

# Evaluate the model performance on the validation set
accuracy_no_outliers_scaled = accuracy_score(y_val_no_outliers, y_pred_no_outliers_scaled)
print(f"Accuracy on the scaled validation set: {accuracy_no_outliers_scaled:.2%}")

# Make predictions on the scaled original test set
test_predictions_scaled = model_no_outliers_scaled.predict(X_test_scaled)


# Optional: Save the predictions to a CSV file
predictions_df_scaled = pd.DataFrame({'Loan_Status_Prediction': test_predictions_scaled})
# predictions_df_scaled.to_csv('test_predictions_scaled.csv', index=False)


# Make predictions on the scaled validation set
y_pred_no_outliers_scaled = model_no_outliers_scaled.predict(X_val_scaled)

# Calculate and print precision, recall, and F1-score
precision_no_outliers_scaled = precision_score(y_val_no_outliers, y_pred_no_outliers_scaled)
recall_no_outliers_scaled = recall_score(y_val_no_outliers, y_pred_no_outliers_scaled)
f1_no_outliers_scaled = f1_score(y_val_no_outliers, y_pred_no_outliers_scaled)

print(f'Precision (scaled): {precision_no_outliers_scaled}')
print(f'Recall (scaled): {recall_no_outliers_scaled}')
print(f'F1-score (scaled): {f1_no_outliers_scaled}')

# Calculate and print confusion matrix
conf_matrix_no_outliers_scaled = confusion_matrix(y_val_no_outliers, y_pred_no_outliers_scaled)
print('Confusion Matrix (scaled):')
print(conf_matrix_no_outliers_scaled)

# Additional classification report
print('Classification Report (scaled):')
print(classification_report(y_val_no_outliers, y_pred_no_outliers_scaled))


# model_filename = 'logistic_regression_model.joblib'
# dump(model_no_outliers_scaled, model_filename)
# print(f"Model saved as {model_filename}")
# Out:
# Accuracy on the scaled validation set: 78.86%
# Precision (scaled): 0.7596153846153846
# Recall (scaled): 0.9875
# F1-score (scaled): 0.8586956521739131
# Confusion Matrix (scaled):
# [[18 25]
#  [ 1 79]]
# Classification Report (scaled):
#               precision    recall  f1-score   support
#
#            0       0.95      0.42      0.58        43
#            1       0.76      0.99      0.86        80
#
#     accuracy                           0.79       123
#    macro avg       0.85      0.70      0.72       123
# weighted avg       0.83      0.79      0.76       123
#
# Model saved as logistic_regression_model.joblib

# %%
import matplotlib.pyplot as plt

# Precision, Recall, and F1-score values
precision = 0.7596153846153846
recall = 0.9875
f1_score = 0.8586956521739131

# Labels for the bars
labels = ['Precision', 'Recall', 'F1-score']

# Values for the bars
values = [precision, recall, f1_score]

# Plotting the bar graph
plt.figure(figsize=(8, 6))
plt.bar(labels, values, color=['blue', 'green', 'orange'])
plt.title('Precision, Recall, and F1-score')
plt.ylim(0, 1)  # Set y-axis limits between 0 and 1 for better visualization
plt.ylabel('Score')
plt.show()

# %% [markdown]
# # Graphical representation of true positive rate

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Get the probability estimates for the positive class (class 1)
y_prob_no_outliers_scaled = model_no_outliers_scaled.predict_proba(X_val_scaled)[:, 1]

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_val_no_outliers, y_prob_no_outliers_scaled)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(10, 5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt

# Number of iterations or any other suitable label
iterations = range(1, len(y_pred_no_outliers_scaled) + 1)

# Accuracy on the scaled validation set for each iteration
accuracies = [accuracy_score(y_val_no_outliers[:i], y_pred_no_outliers_scaled[:i]) for i in iterations]

# Plot the accuracy over iterations
plt.figure(figsize=(10, 5))
plt.plot(iterations, accuracies, label='Accuracy', color='blue', lw=2)
plt.title('Accuracy over Iterations on Scaled Validation Set')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score

# Number of iterations or any other suitable label
iterations = range(1, len(y_pred_no_outliers_scaled) + 1)

# Calculate accuracy, recall, and precision for each iteration
accuracies = [accuracy_score(y_val_no_outliers[:i], y_pred_no_outliers_scaled[:i]) for i in iterations]
recalls = [recall_score(y_val_no_outliers[:i], y_pred_no_outliers_scaled[:i]) for i in iterations]
precisions = [precision_score(y_val_no_outliers[:i], y_pred_no_outliers_scaled[:i]) for i in iterations]

# Plot the metrics over iterations
plt.figure(figsize=(12, 6))
plt.plot(iterations, accuracies, label='Accuracy', color='blue', lw=2)
plt.plot(iterations, recalls, label='Recall', color='green', lw=2)
plt.plot(iterations, precisions, label='Precision', color='orange', lw=2)

plt.title('Metrics over Iterations on Scaled Validation Set')
plt.xlabel('Iteration')
plt.ylabel('Metric Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot confusion matrix heatmap
sns.heatmap(conf_matrix_no_outliers_scaled, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap (scaled)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame with actual and predicted values
results_df = pd.DataFrame({'Actual': y_val_no_outliers, 'Predicted': y_pred_no_outliers_scaled})

# Plot the target values
plt.figure(figsize=(8, 6))
sns.countplot(x='variable', hue='value', data=pd.melt(results_df))
plt.title('Actual vs Predicted Loan Status on Validation Set')
plt.xlabel('Loan Status')
plt.ylabel('Count')
plt.legend(title='Legend', labels=['No Loan', 'Loan Approved'])
plt.show()

# %% [markdown]
# #  predict the result

# %%
import pandas as pd
from joblib import dump, load

# Load the saved model
model_filename = 'logistic_regression_model.joblib'
loaded_model = load(model_filename)


# Take user input for features
user_input = {
    'Gender': input("Gender (Male/Female): "),
    'Married': input("Married (Yes/No): "),
    'Dependents': input("Dependents (0/1/2/3+): "),
    'Education': input("Education (Graduate/Not Graduate): "),
    'Self_Employed': input("Self Employed (Yes/No): "),
    'ApplicantIncome': float(input("Applicant Income: ")),
    'CoapplicantIncome': float(input("Coapplicant Income: ")),
    'LoanAmount': float(input("Loan Amount: ")),
    'Loan_Amount_Term': float(input("Loan Amount Term: ")),
    'Credit_History': float(input("Credit History (1.0/0.0): ")),
    'Property_Area': input("Property Area (Urban/Rural/Semiurban  0/1/2): "),
}

# Create a DataFrame from the user input
user_input_df = pd.DataFrame([user_input])

# Label encode categorical variables
categorical_cols = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area']
for col in categorical_cols:
    user_input_df[col] = label_encoder.transform(user_input_df[col])

# Apply StandardScaler to the user input features
user_input_scaled = scaler.transform(user_input_df)

# Make predictions using the loaded model
user_prediction = loaded_model.predict(user_input_scaled)

# Display the prediction
print(f"Predicted Loan Status: {user_prediction[0]}")
# Out:
# Gender (Male/Female):  1
# Married (Yes/No):  0
# Dependents (0/1/2/3+):  0
# Education (Graduate/Not Graduate):  0
# Self Employed (Yes/No):  0
# Applicant Income:  5849
# Coapplicant Income:  0
# Loan Amount:  1
# Loan Amount Term:  360
# Credit History (1.0/0.0):  1
# Property Area (Urban/Rural/Semiurban  0/1/2):  2
# Predicted Loan Status: 1

# %%
0	0	0	0	1	4583	0	133	360	0	1	N
1	0	0	0	0	5849	0	1	360	1	2	Y

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# Assuming true label for user input data (you might not have this in a real-world scenario)
true_label = [1]  # Replace with the actual label

# Print accuracy
user_accuracy = accuracy_score(true_label, user_prediction)
print(f"User Accuracy: {user_accuracy:.2%}")

# Visualize the result on a graph
labels = ['Rejected', 'Approved']
user_proba = loaded_model.predict_proba(user_input_scaled)[0]  # Probability for each class

# Plotting the probabilities
fig, ax = plt.subplots()
ax.bar(labels, user_proba, color=['red', 'green'])
ax.set_ylabel('Probability')
ax.set_title('Loan Approval Probability')
plt.show()
# Out:
# User Accuracy: 100.00%
